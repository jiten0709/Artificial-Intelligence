# %% [markdown]
# #### Intelligence: The "brain" that processes information and makes decisions using LLMs. This component handles context understanding, instruction following, and response generation.

# %% [markdown]
# #### NOTE: i am using github openai for this example.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI

# %%
TOKEN = os.getenv('GITHUB_TOKEN')
ENDPOINT = os.getenv('GITHUB_ENDPOINT')
MODEL = os.getenv('GITHUB_MODEL_NAME')

# %%
def basic_intelligence(prompt: str) -> str:
    client = OpenAI(
        base_url=ENDPOINT,
        api_key=TOKEN,
    )
    response = client.chat.completions.create(
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        model=MODEL
    )
    
    return response.choices[0].message.content

# %%
result = basic_intelligence(prompt="What is artificial intelligence?")
print("Basic Intelligence Output:")
print(result)
# Out:
# Basic Intelligence Output:
# **Artificial intelligence (AI)** is a branch of computer science focused on creating machines and software that can perform tasks typically requiring human intelligence. These tasks include:
#
# - Understanding language (natural language processing)
# - Recognizing patterns and images (computer vision)
# - Solving problems and making decisions
# - Learning from experience (machine learning)
# - Reasoning and planning
#
# In simple terms, AI enables computers to simulate human-like abilities such as learning, problem solving, and adapting to new situations. Examples include virtual assistants, chatbots, self-driving cars, and recommendation systems (like those used by Netflix or Amazon).
